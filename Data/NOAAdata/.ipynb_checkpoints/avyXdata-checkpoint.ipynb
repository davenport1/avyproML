# %%
# cleaning weather data 2019-2020 for model training/testing
# 
#

import netCDF4 as nc
import pandas as pd
import numpy as np

# %%
# path: C:\Users\daven\Documents\avydatacleaning\NOAAdata
# importing netcdf file


filename = 'weasd.2019.nc'
ds = nc.Dataset(filename)
print(ds)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     Conventions: CF-1.2
#     centerlat: 50.0
#     centerlon: -107.0
#     comments:
#     institution: National Centers for Environmental Prediction
#     latcorners: [ 1.000001  0.897945 46.3544   46.63433 ]
#     loncorners: [-145.5       -68.32005    -2.569891  148.6418  ]
#     platform: Model
#     standardpar1: 50.0
#     standardpar2: 50.000001
#     title: 8x Daily NARR
#     history: created Mon Jul 18 13:39:08 MDT 2016 by NOAA/ESRL/PSD
#     dataset_title: NCEP North American Regional Reanalysis (NARR)
#     references: https://www.esrl.noaa.gov/psd/data/gridded/data.narr.html
#     source: http://www.emc.ncep.noaa.gov/mmb/rreanl/index.html
#     References:
#     dimensions(sizes): time(2920), y(277), x(349)
#     variables(dimensions): float64 time(time), float32 lat(y, x), float32 lon(y, x), float32 y(y), float32 x(x), int32 Lambert_Conformal(), float32 weasd(time, y, x)
#     groups:

# %%
print(ds.variables.keys())
# Out:
# dict_keys(['time', 'lat', 'lon', 'y', 'x', 'Lambert_Conformal', 'weasd'])

# %%
#viewing variables of the netcdf file
print(ds.variables['time'])
print(ds.variables['lat'])
print(ds.variables['lon'])
print(ds.variables['y'])
print(ds.variables['x'])
print(ds.variables['Lambert_Conformal'])
print(ds.variables['weasd'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     axis: T
#     coordinate_defines: start
#     delta_t: 0000-00-00 03:00:00
#     long_name: Time
#     standard_name: time
#     units: hours since 1800-1-1 00:00:0.0
#     actual_range: [1919712. 1928469.]
# unlimited dimensions: time
# current shape = (2920,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 lat(y, x)
#     axis: Y
#     coordinate_defines: point
#     long_name: Latitude
#     standard_name: latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (277, 349)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 lon(y, x)
#     axis: X
#     coordinate_defines: point
#     long_name: Longitude
#     standard_name: longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (277, 349)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 y(y)
#     long_name: northward distance from southwest corner of domain in projection coordinates
#     standard_name: projection_y_coordinate
#     units: m
# unlimited dimensions:
# current shape = (277,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 x(x)
#     long_name: eastward distance from southwest corner of domain in projection coordinates
#     standard_name: projection_x_coordinate
#     units: m
# unlimited dimensions:
# current shape = (349,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 Lambert_Conformal()
#     false_easting: 5632642.22547
#     false_northing: 4612545.65137
#     grid_mapping_name: lambert_conformal_conic
#     latitude_of_projection_origin: 50.0
#     longitude_of_central_meridian: -107.0
#     standard_parallel: [50. 50.]
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 weasd(time, y, x)
#     GRIB_id: 65
#     GRIB_name: WEASD
#     _FillValue: 9.96921e+36
#     coordinates: lat lon
#     dataset: NARR 3-hourly
#     grid_mapping: Lambert_Conformal
#     level_desc: Surface
#     long_name: 3-hourly Accumulated Snow at Surface
#     parent_stat: Other
#     standard_name: surface_snow_amount
#     statistic: Individual Obs
#     units: kg/m^2
#     var_desc: accumulated snow
#     missing_value: -9.96921e+36
#     actual_range: [  0.      722.28125]
#     valid_range: [   0. 3000.]
# unlimited dimensions: time
# current shape = (2920, 277, 349)
# filling on

# %%
# Accessing variables of the netcdf file
time = ds.variables['time'][:]
lat = ds.variables['lat'][:]
lon = ds.variables['lon'][:]
y = ds.variables['y'][:]
x = ds.variables['x'][:]
Lambert_Conformal = ds.variables['Lambert_Conformal'][:]
weasd = ds.variables['weasd'][:]

# showing contents of variables
print(time)
print(lat)
print(lon)
print(y)
print(x)
print(Lambert_Conformal)
print(weasd)
# Out:
# [1919712. 1919715. 1919718. ... 1928463. 1928466. 1928469.]
# [[ 1.000001  1.104305  1.208292 ...  1.106851  1.002554  0.897945]
#  [ 1.184838  1.289653  1.39415  ...  1.292212  1.187404  1.082283]
#  [ 1.369977  1.475305  1.580315 ...  1.477877  1.372555  1.266921]
#  ...
#  [46.52934  46.8157   47.10208  ... 46.8227   46.53634  46.25001 ]
#  [46.58263  46.8693   47.156    ... 46.87632  46.58964  46.303   ]
#  [46.63433  46.9213   47.20831  ... 46.92832  46.64134  46.3544  ]]
# [[-145.5      -145.315    -145.1295   ...  -68.68951   -68.50452
#    -68.32005 ]
#  [-145.6047   -145.4194   -145.2336   ...  -68.58509   -68.39979
#    -68.215   ]
#  [-145.71     -145.5244   -145.3383   ...  -68.48015   -68.29454
#    -68.10945 ]
#  ...
#  [ 149.476     149.555     149.6349   ...   -3.556949   -3.477873
#     -3.399673]
#  [ 149.0593    149.1361    149.2138   ...   -3.137999   -3.061175
#     -2.985206]
#  [ 148.6418    148.7163    148.7917   ...   -2.718174   -2.643617
#     -2.569891]]
# [      0.   32463.   64926.   97389.  129852.  162315.  194778.  227241.
#   259704.  292167.  324630.  357093.  389556.  422019.  454482.  486945.
#   519408.  551871.  584334.  616797.  649260.  681723.  714186.  746649.
#   779112.  811575.  844038.  876501.  908964.  941427.  973890. 1006353.
#  1038816. 1071279. 1103742. 1136205. 1168668. 1201131. 1233594. 1266057.
#  1298520. 1330983. 1363446. 1395909. 1428372. 1460835. 1493298. 1525761.
#  1558224. 1590687. 1623150. 1655613. 1688076. 1720539. 1753002. 1785465.
#  1817928. 1850391. 1882854. 1915317. 1947780. 1980243. 2012706. 2045169.
#  2077632. 2110095. 2142558. 2175021. 2207484. 2239947. 2272410. 2304873.
#  2337336. 2369799. 2402262. 2434725. 2467188. 2499651. 2532114. 2564577.
#  2597040. 2629503. 2661966. 2694429. 2726892. 2759355. 2791818. 2824281.
#  2856744. 2889207. 2921670. 2954133. 2986596. 3019059. 3051522. 3083985.
#  3116448. 3148911. 3181374. 3213837. 3246300. 3278763. 3311226. 3343689.
#  3376152. 3408615. 3441078. 3473541. 3506004. 3538467. 3570930. 3603393.
